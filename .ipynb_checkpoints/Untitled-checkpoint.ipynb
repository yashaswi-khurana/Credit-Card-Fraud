# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import dtale

# %%
df_Train=pd.read_csv('fraudTrain.csv')
df_Test=pd.read_csv('fraudTest.csv')

# %%
df_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
# ...

# %%
df_Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  int64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
df_Train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df_Test.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df=pd.concat([df_Train,df_Test])

# %%
df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2019-01-01 00:00:18  2703186189652095
# 1                1   2019-01-01 00:00:44      630423337322
# 2                2   2019-01-01 00:00:51    38859492057661
# 3                3   2019-01-01 00:01:16  3534093764340240
# 4                4   2019-01-01 00:03:06   375534208663984
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                   merchant        category     amt      first  \
# 0               fraud_Rippin, Kub and Mann        misc_net    4.97   Jennifer
# 1          fraud_Heller, Gutmann and Zieme     grocery_pos  107.23  Stephanie
# ...

# %%
# import dtale.global_state as global_state

# # Set chart settings for D-Tale
# global_state.set_chart_settings({'scatter_points': 15000, '3d_points': 40000})

# %%
# dtale.show(df)

# %%
df.drop(['lat','long','Unnamed: 0','merch_lat','merch_long'],axis=1,inplace=True)

# %%
df[df['is_fraud']==1]['is_fraud'].sum()
# Out:
# 9651

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city state    zip  city_pop  \
# 0                561 Perry Cove  Moravian Falls    NC  28654      3495
# ...

# %%
df['gender']=df['gender'].map({'F':0,'M':1})

# %%
df
# Out:
#        trans_date_trans_time            cc_num  \
# 0        2019-01-01 00:00:18  2703186189652095
# 1        2019-01-01 00:00:44      630423337322
# 2        2019-01-01 00:00:51    38859492057661
# 3        2019-01-01 00:01:16  3534093764340240
# 4        2019-01-01 00:03:06   375534208663984
# ...                      ...               ...
# 555714   2020-12-31 23:59:07    30560609640617
# 555715   2020-12-31 23:59:09  3556613125071656
# 555716   2020-12-31 23:59:15  6011724471098086
# 555717   2020-12-31 23:59:24     4079773899158
# 555718   2020-12-31 23:59:34  4170689372027579
#
#                                   merchant        category     amt      first  \
# 0               fraud_Rippin, Kub and Mann        misc_net    4.97   Jennifer
# 1          fraud_Heller, Gutmann and Zieme     grocery_pos  107.23  Stephanie
# 2                     fraud_Lind-Buckridge   entertainment  220.11     Edward
# 3       fraud_Kutch, Hermiston and Farrell   gas_transport   45.00     Jeremy
# ...

# %%
df['category'].unique()
# Out:
# array(['misc_net', 'grocery_pos', 'entertainment', 'gas_transport',
#        'misc_pos', 'grocery_net', 'shopping_net', 'shopping_pos',
#        'food_dining', 'personal_care', 'health_fitness', 'travel',
#        'kids_pets', 'home'], dtype=object)

# %%
df['category']=df['category'].map({'misc_net':0,'grocery_pos':1,'entertainment':2,'gas_transport':3,'misc_pos':4,'grocery_net':5,'shopping_net':6,'shopping_pos':7,'food_dining':8,'personal_care':9,'health_fitness':10,'travel':11,'kids_pets':12,'home':13})

# %% [markdown]
# 'misc_net':0,'grocery_pos':1,'entertainment':2,'gas_transport':3,'misc_pos':4,'grocery_net':5,'shopping_net':6,'shopping_pos':7,'food_dining':8,'personal_care':9,'health_fitness':10,'travel':11,'kids_pets':12,'home':13

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#    category     amt      first     last  gender                        street  \
# 0         0    4.97   Jennifer    Banks       0                561 Perry Cove
# 1         1  107.23  Stephanie     Gill       0  43039 Riley Greens Suite 393
# 2         2  220.11     Edward  Sanchez       1      594 White Dale Suite 530
# 3         3   45.00     Jeremy    White       1   9443 Cynthia Court Apt. 038
# 4         4   41.96      Tyler   Garcia       1              408 Bradley Rest
#
# ...

# %%
df['dob'] = pd.to_datetime(df['dob'])
df['year'] = df['dob'].dt.year

# %%
df['year'] #Taking reference from 2020, to assume the age we can reference year by dob year
# Out:
# 0         1988
# 1         1978
# 2         1962
# 3         1967
# 4         1986
#           ...
# 555714    1966
# 555715    1999
# 555716    1981
# 555717    1965
# 555718    1993
# Name: year, Length: 1852394, dtype: int64

# %%
df['age']=2020-df['year']

# %%
df['age']
# Out:
# 0         32
# 1         42
# 2         58
# 3         53
# 4         34
#           ..
# 555714    54
# 555715    21
# 555716    39
# 555717    55
# 555718    27
# Name: age, Length: 1852394, dtype: int64

# %%
df.drop(['dob','year','city','state'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#    category     amt      first     last  gender                        street  \
# 0         0    4.97   Jennifer    Banks       0                561 Perry Cove
# 1         1  107.23  Stephanie     Gill       0  43039 Riley Greens Suite 393
# 2         2  220.11     Edward  Sanchez       1      594 White Dale Suite 530
# 3         3   45.00     Jeremy    White       1   9443 Cynthia Court Apt. 038
# 4         4   41.96      Tyler   Garcia       1              408 Bradley Rest
#
# ...

# %%
# dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://yashaswi:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1852394 entries, 0 to 555718
# Data columns (total 16 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trans_date_trans_time  object
#  1   cc_num                 int64
#  2   merchant               object
#  3   category               int64
#  4   amt                    float64
#  5   first                  object
#  6   last                   object
#  7   gender                 int64
#  8   street                 object
#  9   zip                    int64
#  10  city_pop               int64
#  11  job                    object
#  12  trans_num              object
#  13  unix_time              int64
#  14  is_fraud               int64
#  15  age                    int64
# dtypes: float64(1), int64(8), object(7)
# memory usage: 272.5+ MB

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'zip', 'city_pop', 'job',
#        'trans_num', 'unix_time', 'is_fraud', 'age'],
#       dtype='object')

# %%
df['trans_date']=df['trans_date_trans_time'].str.split(' ').apply(lambda x: x[0])

# %%
df['trans_time']=df['trans_date_trans_time'].str.split(' ').apply(lambda x: x[1])

# %%
df.drop('trans_date_trans_time',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1852394 entries, 0 to 555718
# Data columns (total 17 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   cc_num      int64
#  1   merchant    object
#  2   category    int64
#  3   amt         float64
#  4   first       object
#  5   last        object
#  6   gender      int64
#  7   street      object
#  8   zip         int64
#  9   city_pop    int64
#  10  job         object
#  11  trans_num   object
#  12  unix_time   int64
#  13  is_fraud    int64
#  14  age         int64
#  15  trans_date  object
#  16  trans_time  object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 286.6+ MB

# %%
df.tail()
# Out:
#                   cc_num               merchant  category     amt    first  \
# 555714    30560609640617  fraud_Reilly and Sons        10   43.77  Michael
# 555715  3556613125071656   fraud_Hoppe-Parisian        12  111.84     Jose
# 555716  6011724471098086        fraud_Rau-Robel        12   86.88      Ann
# 555717     4079773899158  fraud_Breitenberg LLC        11    7.99     Eric
# 555718  4170689372027579      fraud_Dare-Marvin         2   38.13   Samuel
#
#            last  gender                      street    zip  city_pop  \
# 555714    Olson       1         558 Michael Estates  63453       519
# 555715  Vasquez       1         572 Davis Mountains  77566     28739
# 555716   Lawson       0  144 Evans Islands Apt. 683  99323      3684
# 555717  Preston       1  7020 Doyle Stream Apt. 951  83643       129
# 555718     Frey       1    830 Myers Plaza Apt. 384  73034    116001
#
#                    job                         trans_num   unix_time  \
# ...

# %%
df['amt'].max()
# Out:
# 28948.9

# %%
df['name']=df['first']+ ' ' +df['last']
df['name']
# Out:
# 0         Jennifer Banks
# 1         Stephanie Gill
# 2         Edward Sanchez
# 3           Jeremy White
# 4           Tyler Garcia
#                ...
# 555714     Michael Olson
# 555715      Jose Vasquez
# 555716        Ann Lawson
# 555717      Eric Preston
# 555718       Samuel Frey
# Name: name, Length: 1852394, dtype: object

# %%
df.drop('name',axis=1,inplace=True)
